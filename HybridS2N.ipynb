# %% [markdown]
# # Download Data and Packages

# %%
! wget http://www.ehu.eus/ccwintco/uploads/6/67/Indian_pines_corrected.mat
! wget http://www.ehu.eus/ccwintco/uploads/c/c4/Indian_pines_gt.mat

! wget http://www.ehu.eus/ccwintco/uploads/a/a3/Salinas_corrected.mat
! wget http://www.ehu.eus/ccwintco/uploads/f/fa/Salinas_gt.mat

! wget http://www.ehu.eus/ccwintco/uploads/e/ee/PaviaU.mat
! wget http://www.ehu.eus/ccwintco/uploads/5/50/PaviaU_gt.mat

! pip install spectral
! pip install torch-summary
# Out:
# --2020-10-23 12:06:01--  http://www.ehu.eus/ccwintco/uploads/6/67/Indian_pines_corrected.mat
# Resolving www.ehu.eus (www.ehu.eus)... 158.227.0.65, 2001:720:1410::65
# Connecting to www.ehu.eus (www.ehu.eus)|158.227.0.65|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5953527 (5.7M) [text/plain]
# Saving to: ‘Indian_pines_corrected.mat’
#
# Indian_pines_correc 100%[===================>]   5.68M   868KB/s    in 7.7s
#
# 2020-10-23 12:06:09 (756 KB/s) - ‘Indian_pines_corrected.mat’ saved [5953527/5953527]
#
# --2020-10-23 12:06:09--  http://www.ehu.eus/ccwintco/uploads/c/c4/Indian_pines_gt.mat
# Resolving www.ehu.eus (www.ehu.eus)... 158.227.0.65, 2001:720:1410::65
# Connecting to www.ehu.eus (www.ehu.eus)|158.227.0.65|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1125 (1.1K) [text/plain]
# Saving to: ‘Indian_pines_gt.mat’
#
# Indian_pines_gt.mat 100%[===================>]   1.10K  --.-KB/s    in 0s
#
# 2020-10-23 12:06:09 (156 MB/s) - ‘Indian_pines_gt.mat’ saved [1125/1125]
#
# --2020-10-23 12:06:09--  http://www.ehu.eus/ccwintco/uploads/a/a3/Salinas_corrected.mat
# Resolving www.ehu.eus (www.ehu.eus)... 158.227.0.65, 2001:720:1410::65
# Connecting to www.ehu.eus (www.ehu.eus)|158.227.0.65|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26552770 (25M) [text/plain]
# Saving to: ‘Salinas_corrected.mat’
#
# Salinas_corrected.m 100%[===================>]  25.32M   801KB/s    in 34s
#
# 2020-10-23 12:06:43 (769 KB/s) - ‘Salinas_corrected.mat’ saved [26552770/26552770]
#
# --2020-10-23 12:06:43--  http://www.ehu.eus/ccwintco/uploads/f/fa/Salinas_gt.mat
# Resolving www.ehu.eus (www.ehu.eus)... 158.227.0.65, 2001:720:1410::65
# Connecting to www.ehu.eus (www.ehu.eus)|158.227.0.65|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4277 (4.2K) [text/plain]
# Saving to: ‘Salinas_gt.mat’
#
# Salinas_gt.mat      100%[===================>]   4.18K  --.-KB/s    in 0s
#
# 2020-10-23 12:06:44 (449 MB/s) - ‘Salinas_gt.mat’ saved [4277/4277]
#
# --2020-10-23 12:06:44--  http://www.ehu.eus/ccwintco/uploads/e/ee/PaviaU.mat
# Resolving www.ehu.eus (www.ehu.eus)... 158.227.0.65, 2001:720:1410::65
# Connecting to www.ehu.eus (www.ehu.eus)|158.227.0.65|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34806917 (33M) [text/plain]
# Saving to: ‘PaviaU.mat’
#
# PaviaU.mat          100%[===================>]  33.19M   780KB/s    in 47s
#
# 2020-10-23 12:07:31 (731 KB/s) - ‘PaviaU.mat’ saved [34806917/34806917]
#
# --2020-10-23 12:07:31--  http://www.ehu.eus/ccwintco/uploads/5/50/PaviaU_gt.mat
# Resolving www.ehu.eus (www.ehu.eus)... 158.227.0.65, 2001:720:1410::65
# Connecting to www.ehu.eus (www.ehu.eus)|158.227.0.65|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11005 (11K) [text/plain]
# Saving to: ‘PaviaU_gt.mat’
#
# PaviaU_gt.mat       100%[===================>]  10.75K  --.-KB/s    in 0s
#
# 2020-10-23 12:07:31 (226 MB/s) - ‘PaviaU_gt.mat’ saved [11005/11005]
#
# Collecting spectral
#   Downloading https://files.pythonhosted.org/packages/ce/06/6a89035cde4eac3ed94e1888f850af653386e8ee827edc72ffc8e445bcb7/spectral-0.22.1-py3-none-any.whl (212kB)
#      |████████████████████████████████| 215kB 9.4MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from spectral) (1.18.5)
# Installing collected packages: spectral
# Successfully installed spectral-0.22.1
# Collecting torch-summary
#   Downloading https://files.pythonhosted.org/packages/83/49/f9db57bcad7246591b93519fd8e5166c719548c45945ef7d2fc9fcba46fb/torch_summary-1.4.3-py3-none-any.whl
# Installing collected packages: torch-summary
# Successfully installed torch-summary-1.4.3

# %% [markdown]
# # Import Dependencies

# %%
import torch
from torch import nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchsummary import summary
import torch.nn.functional as F

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, cohen_kappa_score

from operator import truediv
from keras.utils import to_categorical

from plotly.offline import init_notebook_mode

import math
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import scipy.io as sio
import os
import random
import spectral

from google.colab import files

init_notebook_mode(connected=True)
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
DATASET = 'IP'
TEST_RATIO = 0.90
WINDOW_SIZE = 7
COMPONENTS = 30 if DATASET == 'IP' else 15
CLASSES = 9 if (DATASET == 'PU' or DATASET == 'PC') else 16
K1 = 5
K2 = 7

CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda") if CUDA else torch.device("cpu")

LEARNING_RATE = 0.003
EPOCHS = 80
BATCH_SIZE = 100
EXPERIMENTS = 5

if DATASET == 'IP':
    TARGET_NAMES = ['Alfalfa', 'Corn-notill', 'Corn-mintill', 'Corn'
                    ,'Grass-pasture', 'Grass-trees', 'Grass-pasture-mowed', 
                    'Hay-windrowed', 'Oats', 'Soybean-notill', 'Soybean-mintill',
                    'Soybean-clean', 'Wheat', 'Woods', 'Buildings-Grass-Trees-Drives',
                    'Stone-Steel-Towers']
elif DATASET == 'SA':
    TARGET_NAMES = ['Brocoli_green_weeds_1','Brocoli_green_weeds_2','Fallow','Fallow_rough_plow','Fallow_smooth',
                    'Stubble','Celery','Grapes_untrained','Soil_vinyard_develop','Corn_senesced_green_weeds',
                    'Lettuce_romaine_4wk','Lettuce_romaine_5wk','Lettuce_romaine_6wk','Lettuce_romaine_7wk',
                    'Vinyard_untrained','Vinyard_vertical_trellis']
elif DATASET == 'PU':
    TARGET_NAMES = ['Asphalt','Meadows','Gravel','Trees', 'Painted metal sheets','Bare Soil','Bitumen',
                    'Self-Blocking Bricks','Shadows']

FILENAME = 'HybridS2N_'+DATASET+'_WindowSize_'+str(WINDOW_SIZE)+'_TestRatio_'+str(TEST_RATIO)+'_Transformations_'+'_Kernels_'+str(K1)+str(K2)

# %%
def loadData(name):
    data_path = os.path.join(os.getcwd(),'data')
    if name == 'IP':
        data = sio.loadmat(os.path.join('Indian_pines_corrected.mat'))['indian_pines_corrected']
        labels = sio.loadmat(os.path.join('Indian_pines_gt.mat'))['indian_pines_gt']
    elif name == 'SA':
        data = sio.loadmat(os.path.join('Salinas_corrected.mat'))['salinas_corrected']
        labels = sio.loadmat(os.path.join('Salinas_gt.mat'))['salinas_gt']
    elif name == 'PU':
        data = sio.loadmat(os.path.join('PaviaU.mat'))['paviaU']
        labels = sio.loadmat(os.path.join('PaviaU_gt.mat'))['paviaU_gt']
    
    return data, labels

# %%
def splitTrainTestSet(X, y, testRatio, randomState=345):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=testRatio, random_state=randomState,
                                                        stratify=y)
    return X_train, X_test, y_train, y_test

# %%
def applyPCA(X, numComponents=75):
    newX = np.reshape(X, (-1, X.shape[2]))
    pca = PCA(n_components=numComponents, whiten=True)
    newX = pca.fit_transform(newX)
    newX = np.reshape(newX, (X.shape[0],X.shape[1], numComponents))
    return newX, pca

# %%
def padWithZeros(X, margin=2):
    newX = np.zeros((X.shape[0] + 2 * margin, X.shape[1] + 2* margin, X.shape[2]))
    x_offset = margin
    y_offset = margin
    newX[x_offset:X.shape[0] + x_offset, y_offset:X.shape[1] + y_offset, :] = X
    return newX

# %%
def createImageCubes(X, y, windowSize=WINDOW_SIZE, removeZeroLabels = True):
    margin = int((windowSize - 1) / 2)
    zeroPaddedX = padWithZeros(X, margin=margin)
    # split patches
    patchesData = np.zeros((X.shape[0] * X.shape[1], windowSize, windowSize, X.shape[2]))
    patchesLabels = np.zeros((X.shape[0] * X.shape[1]))
    patchIndex = 0
    for r in range(margin, zeroPaddedX.shape[0] - margin):
        for c in range(margin, zeroPaddedX.shape[1] - margin):
            patch = zeroPaddedX[r - margin:r + margin + 1, c - margin:c + margin + 1]   
            patchesData[patchIndex, :, :, :] = patch
            patchesLabels[patchIndex] = y[r-margin, c-margin]
            patchIndex = patchIndex + 1
    if removeZeroLabels:
        patchesData = patchesData[patchesLabels>0,:,:,:]
        patchesLabels = patchesLabels[patchesLabels>0]
        patchesLabels -= 1
    return patchesData, patchesLabels

# %%
def create_train_test_data():
    X, y = loadData(DATASET)

    X, pca = applyPCA(X, numComponents=COMPONENTS)
    X, y = createImageCubes(X, y, windowSize=WINDOW_SIZE)

    Xtrain, Xtest, ytrain, ytest = splitTrainTestSet(X, y, TEST_RATIO)
    return Xtrain, Xtest, ytrain, ytest

# %%
class HSIDataset(Dataset):
  def __init__(self, X, y):
    self.X = X
    self.y = y

  def __len__(self):
    return self.X.shape[0]

  def __getitem__(self, index):
    X = torch.Tensor(self.X[index]).permute(2, 0, 1)
    y = to_categorical(self.y[index], num_classes=CLASSES)

    data = {'image':X, 'label':y}

    return data

# %%
def create_dataloaders(batch_size=BATCH_SIZE):
  Xtrain, Xtest, ytrain, ytest = create_train_test_data()

  train_set = HSIDataset(Xtrain, ytrain)
  test_set = HSIDataset(Xtest, ytest)

  train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
  test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False)

  return train_loader, test_loader

# %%
train_loader, test_loader = create_dataloaders(batch_size=BATCH_SIZE)

# %% [markdown]
# # Define Model

# %%
class BasicBlock(nn.Module):
  def __init__(self, inp, out, kernel_size, stride=1, bn=True, act=True):
    super(BasicBlock, self).__init__()

    self.bn = bn
    self.act = act

    self.conv = nn.Conv2d(inp, out, kernel_size=kernel_size, stride=stride, padding=kernel_size//2, bias=False)

    if bn:
      self.batch_norm = nn.BatchNorm2d(out)
    if act:
      self.act_fn = nn.ReLU()

  def forward(self, x):
    x = self.conv(x)

    if self.bn:
      x = self.batch_norm(x)
    if self.act:
      x = self.act_fn(x)

    return x

# %%
class Basic3DBlock(nn.Module):
  def __init__(self, inp, out, kernel_size, bn=True, act=True):
    super(Basic3DBlock, self).__init__()

    self.bn = bn
    self.act = act

    self.conv = nn.Conv3d(in_channels=inp, out_channels=out, kernel_size=kernel_size, bias=False)

    if bn:
      self.batch_norm = nn.BatchNorm3d(out)
    if act:
      self.act_fn = nn.ReLU()

  def forward(self, x):
    x = self.conv(x)

    if self.bn:
      x = self.batch_norm(x)
    if self.act:
      x = self.act_fn(x)

    return x

# %%
class SK2D(nn.Module):
    def __init__(self, inp, oup, kernel_1=K1, kernel_2=K2):
        super(SK2D, self).__init__()
        self.oup = oup

        self.operation_1 = BasicBlock(inp=inp, out=oup, kernel_size=kernel_1) 
        self.operation_2 = BasicBlock(inp=inp, out=oup, kernel_size=kernel_2)

        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.conv_fc1 = BasicBlock(oup, oup//2, kernel_size=1)
        self.conv_fc2 = BasicBlock(oup//2, oup*2, kernel_size=1, bn=False, act=False)     

    def forward(self, x):
        x1 = self.operation_1(x)
        x2 = self.operation_2(x)

        s = self.avg_pool(x1 + x2)
        z = self.conv_fc1(s)
        z = self.conv_fc2(z)

        z = torch.unsqueeze(z, 1).view(-1, 2, self.oup, 1, 1)
        z = F.softmax(z, 1)

        d1 = x1 * z[:, 0, :, :, :].squeeze(1)
        d2 = x2 * z[:, 1, :, :, :].squeeze(1)

        out  = d1 + d2
        return out

# %%
class HybridS2N(nn.Module):
  def __init__(self, classes=CLASSES, kernel_1=K1, kernel_2=K2):
    super(HybridS2N, self).__init__()

    self.conv3d_1 = Basic3DBlock(inp=1, out=8, kernel_size=(7, 3, 3))
    self.conv3d_2 = Basic3DBlock(inp=8, out=16, kernel_size=(5, 3, 3))
    self.conv3d_3 = Basic3DBlock(inp=16, out=32, kernel_size=(3, 3, 3))

    c = COMPONENTS - 12
    self.sk = SK2D(32*c, 64, kernel_1=kernel_1, kernel_2=kernel_2)

    self.avgpool = nn.AdaptiveAvgPool2d(1)
    self.fc = nn.Linear(64, classes)

  def forward(self, x):
    x = x.unsqueeze(1)
    x = self.conv3d_1(x)
    x = self.conv3d_2(x)
    x = self.conv3d_3(x)

    shape = x.size()
    x = x.view(shape[0], -1, shape[3], shape[4])

    x = self.sk(x)
    x = self.avgpool(x)

    x = x.view(x.size(0), -1)
    x = self.fc(x)

    return x

# %%
model = HybridS2N().to(DEVICE)
# o = model(torch.randn((2, 15, 15, 15)).to(DEVICE))
# print(o.shape)
summary(model, input_size=(15, 15, 15), verbose=0, depth=3)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Basic3DBlock: 1-1                      --
# |    └─Conv3d: 2-1                       504
# |    └─BatchNorm3d: 2-2                  16
# |    └─ReLU: 2-3                         --
# ├─Basic3DBlock: 1-2                      --
# |    └─Conv3d: 2-4                       5,760
# |    └─BatchNorm3d: 2-5                  32
# |    └─ReLU: 2-6                         --
# ├─Basic3DBlock: 1-3                      --
# |    └─Conv3d: 2-7                       13,824
# |    └─BatchNorm3d: 2-8                  64
# |    └─ReLU: 2-9                         --
# ├─SK2D: 1-4                              --
# |    └─BasicBlock: 2-10                  --
# |    |    └─Conv2d: 3-1                  921,600
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─ReLU: 3-3                    --
# |    └─BasicBlock: 2-11                  --
# |    |    └─Conv2d: 3-4                  1,806,336
# |    |    └─BatchNorm2d: 3-5             128
# |    |    └─ReLU: 3-6                    --
# |    └─AdaptiveAvgPool2d: 2-12           --
# |    └─BasicBlock: 2-13                  --
# |    |    └─Conv2d: 3-7                  2,048
# |    |    └─BatchNorm2d: 3-8             64
# |    |    └─ReLU: 3-9                    --
# |    └─BasicBlock: 2-14                  --
# |    |    └─Conv2d: 3-10                 4,096
# ├─AdaptiveAvgPool2d: 1-5                 --
# ├─Linear: 1-6                            1,040
# =================================================================
# Total params: 2,755,640
# Trainable params: 2,755,640
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# # Model Training

# %%
def test_model(model, test_loader, criterion, device):
  test_accuracy = 0
  test_loss = 0
  true_labels = []
  pred_labels = []

  model.eval()
  with torch.no_grad():
    for batch in test_loader:
      image_batch = batch['image'].to(device)
      label_batch = batch['label'].to(device)
      _, label_batch = torch.max(label_batch, 1)

      y_pred = model(image_batch)
      batch_loss = criterion(y_pred, label_batch)

      _, output_labels = torch.max(y_pred, 1)
      correct = label_batch.eq(output_labels).cpu().numpy()

      test_accuracy += sum(correct)
      test_loss += batch_loss.item() * image_batch.size(0)

      true_labels += list(label_batch.cpu().numpy())
      pred_labels += list(output_labels.cpu().numpy())

  average_testing_loss = test_loss / len(test_loader.sampler)
  average_testing_accuracy = test_accuracy / len(test_loader.sampler)

  return average_testing_loss, average_testing_accuracy, true_labels, pred_labels

# %%
def train_model(model, train_loader, test_loader, optimizer, criterion, epochs, device, save_path):
  min_train_loss = np.inf

  train_losses = []
  test_losses = []
  train_accuracies = []
  test_accuracies = []

  for epoch in range(epochs):
    train_loss = 0
    test_loss = 0
    train_accuracy = 0
    test_accuracy = 0

    model.train()
    for batch in train_loader:
      image_batch = batch['image'].to(device)
      label_batch = batch['label'].to(device)
      _, label_batch = torch.max(label_batch, 1)

      optimizer.zero_grad()
      y_pred = model(image_batch)
      batch_loss = criterion(y_pred, label_batch)
      batch_loss.backward()
      optimizer.step()

      _, output_labels = torch.max(y_pred, 1)
      correct = label_batch.eq(output_labels).cpu().numpy()
      train_accuracy += sum(correct)
      train_loss += batch_loss.item() * image_batch.size(0)

    average_training_loss = train_loss / len(train_loader.sampler)
    average_training_accuracy = train_accuracy / len(train_loader.sampler)

    average_testing_loss, average_testing_accuracy, _, _ = test_model(
        model, test_loader, 
        criterion, device
        )    
    
    train_losses.append(average_training_loss)
    test_losses.append(average_testing_loss)
    train_accuracies.append(average_training_accuracy)
    test_accuracies.append(average_testing_accuracy)
    
    if min_train_loss > average_training_loss :
      print('Saving at Epoch: {} \t Train Loss: {:.6f} \t Test Loss: {:.6f} \t Train Accuracy: {:.4f} \t Test Accuracy: {:.4f}'.format(epoch, average_training_loss, average_testing_loss, average_training_accuracy, average_testing_accuracy))
      #print('Training Loss Improved - Saving Model')
      
      min_train_loss = average_training_loss
      torch.save(model.state_dict(), save_path)      
  
  return train_losses, test_losses, train_accuracies, test_accuracies

# %%
def random_seed(n):
  torch.manual_seed(n)
  np.random.seed(n)
  random.seed(n)

  if CUDA:
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
train_loader, test_loader = create_dataloaders(batch_size=BATCH_SIZE)

# %%
for e in range(EXPERIMENTS):
  random_seed(e)
  print("Training Experiment "+str(e+1))

  model = HybridS2N().to(DEVICE)

  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=LEARNING_RAT
	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9607
# Saving at Epoch: 16 	 Train Loss: 0.005040 	 Test Loss: 0.122067 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9636
# Saving at Epoch: 17 	 Train Loss: 0.003261 	 Test Loss: 0.117540 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9647
# Saving at Epoch: 18 	 Train Loss: 0.002722 	 Test Loss: 0.115089 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9651
# Saving at Epoch: 19 	 Train Loss: 0.002316 	 Test Loss: 0.112767 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9656
# Saving at Epoch: 20 	 Train Loss: 0.001843 	 Test Loss: 0.114495 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9652
# Saving at Epoch: 21 	 Train Loss: 0.001734 	 Test Loss: 0.113085 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9655
# Saving at Epoch: 23 	 Train Loss: 0.001534 	 Test Loss: 0.117784 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9650
# Saving at Epoch: 24 	 Train Loss: 0.001329 	 Test Loss: 0.122790 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9637
# Saving at Epoch: 32 	 Train Loss: 0.001307 	 Test Loss: 0.122024 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9642
# Saving at Epoch: 33 	 Train Loss: 0.001231 	 Test Loss: 0.117433 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9643
# Saving at Epoch: 34 	 Train Loss: 0.000981 	 Test Loss: 0.114835 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9650
# Saving at Epoch: 35 	 Train Loss: 0.000786 	 Test Loss: 0.117604 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9652
# Saving at Epoch: 36 	 Train Loss: 0.000735 	 Test Loss: 0.119367 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9655
# Saving at Epoch: 39 	 Train Loss: 0.000673 	 Test Loss: 0.125513 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9644
# Saving at Epoch: 60 	 Train Loss: 0.000644 	 Test Loss: 0.122291 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9653
# Saving at Epoch: 61 	 Train Loss: 0.000522 	 Test Loss: 0.120505 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9654
# Saving at Epoch: 63 	 Train Loss: 0.000511 	 Test Loss: 0.123915 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9659
# Saving at Epoch: 64 	 Train Loss: 0.000481 	 Test Loss: 0.122702 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9660
# Saving at Epoch: 65 	 Train Loss: 0.000441 	 Test Loss: 0.122002 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9667
# Saving at Epoch: 66 	 Train Loss: 0.000382 	 Test Loss: 0.123684 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9663
# Saving at Epoch: 68 	 Train Loss: 0.000381 	 Test Loss: 0.124445 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9665
# Saving at Epoch: 70 	 Train Loss: 0.000295 	 Test Loss: 0.125084 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9667
# Saving at Epoch: 73 	 Train Loss: 0.000290 	 Test Loss: 0.122653 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9661
# Saving at Epoch: 74 	 Train Loss: 0.000271 	 Test Loss: 0.121965 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9663
# Saving at Epoch: 78 	 Train Loss: 0.000265 	 Test Loss: 0.124591 	 Train Accuracy: 1.0000 	 Test Accuracy: 0.9665

# %% [markdown]
# # Model Validation

# %%
def AA_andEachClassAccuracy(confusion_matrix):
    counter = confusion_matrix.shape[0]
    list_diag = np.diag(confusion_matrix)
    list_raw_sum = np.sum(confusion_matrix, axis=1)

    each_acc = np.nan_to_num(truediv(list_diag, list_raw_sum))
    each_acc_dict = dict(zip(TARGET_NAMES, each_acc*100))

    average_acc = np.mean(each_acc)
    return each_acc_dict, average_acc

# %%
def reports(y_pred, y_true):    
    c_report = classification_report(y_true, y_pred, digits=4, target_names=TARGET_NAMES)
    oa = accuracy_score(y_true, y_pred)

    confusion = confusion_matrix(y_true, y_pred)
    each_acc, aa = AA_andEachClassAccuracy(confusion)

    kappa = cohen_kappa_score(y_true, y_pred)    
    return c_report, confusion, oa*100, each_acc, aa*100, kappa*100

# %%
def generate_results(c_report, each_acc, kappa, oa, aa, file_name = "classification_report.txt"):

  file_name = os.path.join("Results", file_name)

  c_report = str(c_report)
  each_acc = str(each_acc)

  with open(file_name, 'w') as x_file:
      x_file.write('\n')
      x_file.write('{} Kappa accuracy (%)'.format(kappa))
      x_file.write('\n')
      x_file.write('{} Overall accuracy (%)'.format(oa))
      x_file.write('\n')
      x_file.write('{} Average accuracy (%)'.format(aa))
      x_file.write('\n')
      x_file.write('\n')
      x_file.write('Classification Report - \n')
      x_file.write('{}'.format(c_report))
      x_file.write('\n')
      x_file.write('\n')
      x_file.write('Class-Wise Accuracies - \n')
      x_file.write('{}'.format(each_acc))

# %%
# def generate_confusion_matrix(cm, filename="cm.png"):
#   filename = os.path.join("Results", filename)
#   sb.set(font_scale=1)

#   plt.figure(figsize=(14, 14))
#   plt.axis('on')
#   sb.heatmap(cm, annot=True, fmt="d", linewidths=0, xticklabels=TARGET_NAMES, yticklabels=TARGET_NAMES)

#   plt.savefig(filename)
#   plt.show()

# %%
def generate_averaged_results(oas, aas, kappas, each_accs, file_name = "average_report.txt"):
  file_name = os.path.join("Results", file_name)

  oa_mean = round(np.mean(oas), 2)
  oa_std = round(np.std(oas), 1)

  kappa_mean = round(np.mean(kappas), 2)
  kappa_std = round(np.std(kappas), 1)

  aa_mean = round(np.mean(aas), 2)
  aa_std = round(np.std(aas), 1)

  each_accs_mean = [round(n, 2) for n in np.mean(np.array(each_accs), axis=0)]
  each_accs_std = [round(n, 1) for n in np.std(np.array(each_accs), axis=0)]

  with open(file_name, 'w') as x_file:
      x_file.write('\n')
      x_file.write('${} \pm {}$ Overall accuracy (%)'.format(oa_mean, oa_std))

      x_file.write('\n')
      x_file.write('${} \pm {}$ Kappa accuracy (%)'.format(kappa_mean, kappa_std))

      x_file.write('\n')
      x_file.write('${} \pm {}$ Average accuracy (%)'.format(aa_mean, aa_std))

      x_file.write('\n')
      x_file.write('\n')
      x_file.write('Class-Wise Accuracies are as follows : \n \n')

      for c in range(CLASSES):         
        x_file.write('{} - ${} \pm {}$ \n'.format(TARGET_NAMES[c], each_accs_mean[c], each_accs_std[c]))

# %%
oas = []
aas = []
kappas = []
each_accs = []

if not os.path.exists("Results"):
    os.makedirs("Results")

for e in range(EXPERIMENTS):
  model = HybridS2N().to(DEVICE)
  weights_path = FILENAME+'_Experiment_'+str(e+1)+'.pt'
  model.load_state_dict(torch.load(weights_path))

  _, _, y_true, y_pred = test_model(
        model=model, 
        test_loader=test_loader, 
        criterion=criterion, 
        device=DEVICE
        )

  c_report, confusion, oa, each_acc, aa, kappa = reports(y_pred, y_true)

  oas.append(oa)
  aas.append(aa)
  kappas.append(kappa)
  each_accs.append(list(each_acc.values()))

  generate_results(c_report, each_acc, kappa, oa, aa, file_name=FILENAME+'_Experiment_'+str(e+1)+'.txt')
  # generate_confusion_matrix(confusion, filename=FILENAME+'_Experiment_CMatrix_'+str(e+1)+'.png')
  print("Generated results for Experiment "+str(e+1))

generate_averaged_results(oas, aas, kappas, each_accs, file_name = FILENAME+'_Overall_.txt')
print("Overall results generated !")
# Out:
# Generated results for Experiment 1
# Generated results for Experiment 2
# Generated results for Experiment 3
# Generated results for Experiment 4
# Generated results for Experiment 5
# Overall results generated !

# %%
def Patch(data, height_index, width_index):
    height_slice = slice(height_index, height_index+WINDOW_SIZE)
    width_slice = slice(width_index, width_index+WINDOW_SIZE)
    patch = data[height_slice, width_slice, :]
    
    return patch

# %%
def create_predicted_image():
    model = HybridS2N().to(DEVICE)
    weights_path = FILENAME+'_Experiment_1.pt'
    model.load_state_dict(torch.load(weights_path))

    X, y = loadData(DATASET)

    X, pca = applyPCA(X, numComponents=COMPONENTS)
    X = padWithZeros(X, WINDOW_SIZE//2)

    height = y.shape[0]
    width = y.shape[1]

    outputs = np.zeros((height,width))

    for i in range(height):
      for j in range(width):
          target = int(y[i, j])
          if target == 0 :
              continue
          else :
              image_patch = Patch(X, i, j)
              X_test_image = torch.Tensor(image_patch.astype('float32')).permute(2, 0, 1).unsqueeze(0).to(DEVICE)

              model.eval()
              prediction = np.array(model(X_test_image).cpu().argmax(axis=1)) #torch.max(model(X_test_image), 1)

              prediction = prediction[0] + 1            
              outputs[i][j] = prediction

    return y, outputs

# %%
y, outputs = create_predicted_image()

# %%
ground_truth = spectral.imshow(classes = y, figsize =(12,12), interpolation="none")
plt.axis("off")

filename = FILENAME+'_Experiment_1_Ground_Truth.png'
filename = os.path.join("Results", filename)

plt.savefig(filename)
plt.show()

# %%
predict_image = spectral.imshow(classes = outputs.astype(int), figsize =(12,12), interpolation="none")
plt.axis("off")

filename = FILENAME+'_Experiment_1_Predicted.png'
filename = os.path.join("Results", filename)

plt.savefig(filename)
plt.show()

# %%
# spectral.save_rgb("predictions.jpg", outputs.astype(int), colors=spectral.spy_colors)

# %% [markdown]
# # T-SNE Visualization

# %%
activation = {}
def get_activation(name):
    def hook(model, input, output):
        activation[name] = output.detach()
    return hook

# %%
model = HybridS2N().to(DEVICE)
weights_path = FILENAME+'_Experiment_1.pt'
model.load_state_dict(torch.load(weights_path))

model.avgpool.register_forward_hook(get_activation('avgpool'))
features = np.empty((0, 64))
labels = np.empty((0))

model.eval()
with torch.no_grad():
  for batch in test_loader:
      image_batch = batch['image'].to(DEVICE)
      label_batch = batch['label'].to(DEVICE)
      
      output = model(image_batch)
      _, batch_labels = torch.max(label_batch, 1)

      batch_features = activation['avgpool'].squeeze(-1).squeeze(-1).cpu().numpy()
      batch_labels = [TARGET_NAMES[int(l)] for l in batch_labels.cpu().numpy()]

      features = np.concatenate((features, batch_features))
      labels = np.concatenate((labels, batch_labels))

# %%
tsne = TSNE(n_components=2, perplexity=50).fit_transform(features)

# %%
def scale_to_01_range(x):
    value_range = (np.max(x) - np.min(x))
    starts_from_zero = x - np.min(x)
    return starts_from_zero / value_range

def generate_tsne_plot(tsne, filename='Tsne.png'):
  filename = os.path.join("Results", filename)

  tx = tsne[:, 0]
  ty = tsne[:, 1]

  tx_scaled = scale_to_01_range(tx)
  ty_scaled = scale_to_01_range(ty)

  plt.figure(figsize=(12, 12))
  sb.set(font_scale=1.2)

  sb.scatterplot(tx_scaled, ty_scaled, hue=labels, legend='full', palette=sb.color_palette("bright", len(TARGET_NAMES)))
  plt.legend(loc='best', bbox_to_anchor=(1, 0.5))
  plt.grid(b=None)

  plt.savefig(filename, bbox_inches='tight') #, bbox_inches='tight'
  plt.show()

# %%
generate_tsne_plot(tsne, filename=FILENAME+'_Experiment_1_Tsne.png')
